# %%
from utils import *

# %% [markdown]
# # Marcus Initial Design

# %%
# Position of coils in (R, Z) pairs for coils located at (R, Z) and (R, -Z)
mirrored_PF_coils_positions = [
    (0.22, 0.3),
    (0.40, 0.27),
    (0.52, 0.15)
]

g = generate_geometry(mirrored_PF_coils_positions)
eq = generate_equilibrium(g)
printResult(eq)
# Out:
# Plasma Properties:
# 	Plasma Current       10000.00
# 	Plasma Elongation        1.42
# 	Plasma Triangularly      0.11
# 	Plasma Volume            0.11
#
# Current Profile
# 	 PF0_U: Current:  4015.96 A
# 	 PF0_L: Current:  4015.96 A
# 	 PF1_U: Current:  1287.88 A
# 	 PF1_L: Current:  1287.90 A
# 	 PF2_U: Current: -3685.56 A
# 	 PF2_L: Current: -3685.59 A
# 	 CS: Current:     0.00 A
#
# Force on Coils
# Force on PF0_U:
# 	F_R =    55.07 N
# 	F_Z =   -14.59 N
# Force on PF0_L:
# 	F_R =    55.07 N
# 	F_Z =    14.59 N
# Force on PF1_U:
# 	F_R =   -13.78 N
# 	F_Z =    -1.37 N
# Force on PF1_L:
# 	F_R =   -13.78 N
# 	F_Z =     1.37 N
# Force on PF2_U:
# 	F_R =    79.03 N
# 	F_Z =    10.97 N
# Force on PF2_L:
# 	F_R =    79.03 N
# 	F_Z =   -10.97 N

# %%
# Position of coils in (R, Z) pairs for coils located at (R, Z) and (R, -Z)
mirrored_PF_coils_positions = [
    (0.175, 0.275),
    (0.40, 0.275),
    (0.54, 0.12)
]

g = generate_geometry(mirrored_PF_coils_positions)
eq = generate_equilibrium(g)
printResult(eq)
# Out:
# Warning: No O points found
# Plasma Properties:
# 	Plasma Current       10000.00
# 	Plasma Elongation        1.42
# 	Plasma Triangularly     -0.04
# 	Plasma Volume            0.06
#
# Current Profile
# 	 PF0_U: Current:   725.46 A
# 	 PF0_L: Current:   725.59 A
# 	 PF1_U: Current:  2583.01 A
# 	 PF1_L: Current:  2582.76 A
# 	 PF2_U: Current: -5205.95 A
# 	 PF2_L: Current: -5204.93 A
# 	 CS: Current:     0.00 A
#
# Force on Coils
# Force on PF0_U:
# 	F_R =     3.04 N
# 	F_Z =    -1.73 N
# Force on PF0_L:
# 	F_R =     3.04 N
# 	F_Z =     1.73 N
# Force on PF1_U:
# 	F_R =   -30.65 N
# 	F_Z =    15.27 N
# Force on PF1_L:
# 	F_R =   -30.65 N
# 	F_Z =   -15.27 N
# Force on PF2_U:
# 	F_R =   133.34 N
# 	F_Z =   -59.60 N
# Force on PF2_L:
# 	F_R =   133.30 N
# 	F_Z =    59.59 N

# %%
# Position of coils in (R, Z) pairs for coils located at (R, Z) and (R, -Z)
mirrored_PF_coils_positions = [
    (0.20, 0.275),
    (0.425, 0.275),
    (0.65, 0.15)
]

g = generate_geometry(mirrored_PF_coils_positions)
eq = generate_equilibrium(g)
printResult(eq)
# Out:
# Plasma Properties:
# 	Plasma Current       10000.00
# 	Plasma Elongation        2.06
# 	Plasma Triangularly     -0.11
# 	Plasma Volume            0.09
#
# Current Profile
# 	 PF0_U: Current:  6453.39 A
# 	 PF0_L: Current:  6446.93 A
# 	 PF1_U: Current:  3922.71 A
# 	 PF1_L: Current:  4625.53 A
# 	 PF2_U: Current: -5492.86 A
# 	 PF2_L: Current: -8493.11 A
# 	 CS: Current:     0.00 A
#
# Force on Coils
# Force on PF0_U:
# 	F_R =   138.08 N
# 	F_Z =   -24.71 N
# Force on PF0_L:
# 	F_R =   137.31 N
# 	F_Z =    25.62 N
# Force on PF1_U:
# 	F_R =   -62.17 N
# 	F_Z =    -2.09 N
# Force on PF1_L:
# 	F_R =   -93.86 N
# 	F_Z =    -2.21 N
# Force on PF2_U:
# 	F_R =   188.62 N
# 	F_Z =   -85.99 N
# Force on PF2_L:
# 	F_R =   345.88 N
# 	F_Z =    85.59 N

# %%
# Position of coils in (R, Z) pairs for coils located at (R, Z) and (R, -Z)
mirrored_PF_coils_positions = [
    (0.20, 0.575),
    (0.475, 0.45),
    (0.65, 0.15)
]

g = generate_geometry(mirrored_PF_coils_positions)
eq = generate_equilibrium(g)
printResult(eq)
# Out:
# Plasma Properties:
# 	Plasma Current       10000.00
# 	Plasma Elongation        1.46
# 	Plasma Triangularly     -0.06
# 	Plasma Volume            0.09
#
# Current Profile
# 	 PF0_U: Current:  2767.26 A
# 	 PF0_L: Current:  2760.18 A
# 	 PF1_U: Current:  6517.15 A
# 	 PF1_L: Current:  6520.75 A
# 	 PF2_U: Current: -6778.49 A
# 	 PF2_L: Current: -6782.86 A
# 	 CS: Current:     0.00 A
#
# Force on Coils
# Force on PF0_U:
# 	F_R =    34.68 N
# 	F_Z =    -4.07 N
# Force on PF0_L:
# 	F_R =    34.56 N
# 	F_Z =     4.06 N
# Force on PF1_U:
# 	F_R =    18.57 N
# 	F_Z =    55.81 N
# Force on PF1_L:
# 	F_R =    18.62 N
# 	F_Z =   -55.85 N
# Force on PF2_U:
# 	F_R =   195.96 N
# 	F_Z =   -119.91 N
# Force on PF2_L:
# 	F_R =   196.15 N
# 	F_Z =   119.96 N
