# %%
from utils import *

# %%
# Position of coils in (R, Z) pairs for coils located at (R, Z) and (R, -Z)
mirrored_PF_coils_positions = [
    (0.22, 0.3),
    (0.40, 0.27),
    (0.52, 0.15)
]

g = generate_geometry(mirrored_PF_coils_positions)
eq = generate_equilibrium(g)
printResult(eq)
# Out:
# Plasma Properties:
# 	Plasma Current       10000.00
# 	Plasma Elongation        1.42
# 	Plasma Triangularly      0.11
# 	Plasma Volume            0.11
#
# Current Profile
# 	 PF0_U: Current:  4015.96 A
# 	 PF0_L: Current:  4015.96 A
# 	 PF1_U: Current:  1287.88 A
# 	 PF1_L: Current:  1287.90 A
# 	 PF2_U: Current: -3685.56 A
# 	 PF2_L: Current: -3685.59 A
# 	 CS: Current:     0.00 A
#
# Force on Coils
# Force on PF0_U:
# 	F_R =    55.07 N
# 	F_Z =   -14.59 N
# Force on PF0_L:
# 	F_R =    55.07 N
# 	F_Z =    14.59 N
# Force on PF1_U:
# 	F_R =   -13.78 N
# 	F_Z =    -1.37 N
# Force on PF1_L:
# 	F_R =   -13.78 N
# 	F_Z =     1.37 N
# Force on PF2_U:
# 	F_R =    79.03 N
# 	F_Z =    10.97 N
# Force on PF2_L:
# 	F_R =    79.03 N
# 	F_Z =   -10.97 N

# %%
# Position of coils in (R, Z) pairs for coils located at (R, Z) and (R, -Z)
mirrored_PF_coils_positions = [
    (0.20, 0.30),
    (0.375, 0.25),
    (0.52, 0.15)
]

g = generate_geometry(mirrored_PF_coils_positions)
eq = generate_equilibrium(g)
printResult(eq)
# Out:
# Plasma Properties:
# 	Plasma Current       10000.00
# 	Plasma Elongation        1.03
# 	Plasma Triangularly      0.11
# 	Plasma Volume            0.00
#
# Current Profile
# 	 PF0_U: Current:  1021.16 A
# 	 PF0_L: Current:  1021.16 A
# 	 PF1_U: Current:   976.09 A
# 	 PF1_L: Current:   976.09 A
# 	 PF2_U: Current: -1909.97 A
# 	 PF2_L: Current: -1909.97 A
# 	 CS: Current:     0.00 A
#
# Force on Coils
# Force on PF0_U:
# 	F_R =     3.39 N
# 	F_Z =    -1.99 N
# Force on PF0_L:
# 	F_R =     3.39 N
# 	F_Z =     1.99 N
# Force on PF1_U:
# 	F_R =    -6.58 N
# 	F_Z =     1.52 N
# Force on PF1_L:
# 	F_R =    -6.58 N
# 	F_Z =    -1.52 N
# Force on PF2_U:
# 	F_R =    18.72 N
# 	F_Z =    -5.50 N
# Force on PF2_L:
# 	F_R =    18.72 N
# 	F_Z =     5.50 N

# %%
# Position of coils in (R, Z) pairs for coils located at (R, Z) and (R, -Z)
mirrored_PF_coils_positions = [
    (0.175, 0.225),
    (0.35, 0.275),
    (0.52, 0.15)
]

g = generate_geometry(mirrored_PF_coils_positions)
eq = generate_equilibrium(g)
printResult(eq)
# Out:
# Plasma Properties:
# 	Plasma Current       10000.00
# 	Plasma Elongation        1.31
# 	Plasma Triangularly     -0.01
# 	Plasma Volume            0.08
#
# Current Profile
# 	 PF0_U: Current:  -185.40 A
# 	 PF0_L: Current:  -186.55 A
# 	 PF1_U: Current:  1353.83 A
# 	 PF1_L: Current:  1354.63 A
# 	 PF2_U: Current: -4159.06 A
# 	 PF2_L: Current: -4163.17 A
# 	 CS: Current:     0.00 A
#
# Force on Coils
# Force on PF0_U:
# 	F_R =    -0.60 N
# 	F_Z =     0.73 N
# Force on PF0_L:
# 	F_R =    -0.60 N
# 	F_Z =    -0.73 N
# Force on PF1_U:
# 	F_R =   -12.44 N
# 	F_Z =    -0.31 N
# Force on PF1_L:
# 	F_R =   -12.46 N
# 	F_Z =     0.31 N
# Force on PF2_U:
# 	F_R =    84.09 N
# 	F_Z =   -11.89 N
# Force on PF2_L:
# 	F_R =    84.21 N
# 	F_Z =    11.88 N
