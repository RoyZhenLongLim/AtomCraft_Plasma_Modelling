# %%
from sensitivity_training_poloidal_coils import sensitivity_training_poloidal_coils

# %%
for r1 in [-0.05, 0, 0.05]:
    for r2 in [-0.05, 0, 0.05]:
        for z1 in [0]:
            for z2 in [0]:
                sensitivity_training_poloidal_coils(r1, r2, z1, z2)
print('Done')
# Out:
# ...
# Adjustments: r1: -0.05, r2: -0.05, z1: 0, z2: 0
# Plasma current: 3.00E+03 Amps
# Plasma pressure on axis: 6.76E+00 Pascals
# Poloidal beta: 5.02E-02
# Current
# SOL: 0.00A
# VERT: 1952.69A
# HORIZ: -2165.58A
# Forces
# VERT_U: [17.08757274  7.10581462]
# VERT_L: [17.08757274 -7.10581462]
# HORIZ_U: [41.60440774 -9.04934074]
# HORIZ_L: [41.60440774  9.04934074]
# ...
#
# ...
# Adjustments: r1: -0.05, r2: 0, z1: 0, z2: 0
# Plasma current: 3.00E+03 Amps
# Plasma pressure on axis: 6.76E+00 Pascals
# Poloidal beta: 5.02E-02
# Current
# SOL: 0.00A
# VERT: 1952.69A
# HORIZ: -2165.58A
# Forces
# VERT_U: [17.08757274  7.10581462]
# VERT_L: [17.08757274 -7.10581462]
# HORIZ_U: [41.60440774 -9.04934074]
# HORIZ_L: [41.60440774  9.04934074]
# ...
#
# ...
# Adjustments: r1: -0.05, r2: 0.05, z1: 0, z2: 0
# Plasma current: 3.00E+03 Amps
# Plasma pressure on axis: 6.76E+00 Pascals
# Poloidal beta: 5.02E-02
# Current
# SOL: 0.00A
# VERT: 1952.69A
# HORIZ: -2165.58A
# Forces
# VERT_U: [17.08757274  7.10581462]
# ...
